# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from decimal import Decimal
import seaborn as sn

# %% [markdown]
# # Reading The File

# %%
f=pd.read_csv('h1b.csv')
len(f)
# Out:
# 3002458

# %%
f=f.dropna()
f.reset_index()
lng=len(f)
print(lng)
# Out:
# 2877765

# %%
f
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# 22               23            CERTIFIED
# 23               24            CERTIFIED
# ...

# %% [markdown]
# # Top 15 Employers

# %%
f.EMPLOYER_NAME.value_counts().head(15)
# Out:
# INFOSYS LIMITED                                    130257
# TATA CONSULTANCY SERVICES LIMITED                   64273
# WIPRO LIMITED                                       45673
# DELOITTE CONSULTING LLP                             35999
# IBM INDIA PRIVATE LIMITED                           33585
# ACCENTURE LLP                                       33226
# MICROSOFT CORPORATION                               25551
# HCL AMERICA, INC.                                   22488
# ERNST & YOUNG U.S. LLP                              18094
# COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION     17322
# CAPGEMINI AMERICA INC                               16628
# GOOGLE INC.                                         16425
# LARSEN & TOUBRO INFOTECH LIMITED                    14318
# IGATE TECHNOLOGIES INC.                             12327
# IBM CORPORATION                                     11976
# Name: EMPLOYER_NAME, dtype: int64

# %%
f.EMPLOYER_NAME.value_counts().head(15).plot(kind='bar', title='Top 15 Hiring Company', grid=True, color='Orchid')

# %% [markdown]
# # Analyzing The Wages

# %%
f.PREVAILING_WAGE.value_counts().sort_values(ascending=False).head()
# Out:
# 60000.0    10185
# 55245.0     6745
# 62566.0     6480
# 58053.0     5683
# 52499.0     5492
# Name: PREVAILING_WAGE, dtype: int64

# %% [markdown]
# # Calculating The Mean

# %%
f.PREVAILING_WAGE.mean()
# Out:
# 145166.64888401062

# %% [markdown]
# # Wages Given By The Employers

# %%
awp=f.groupby(['EMPLOYER_NAME']).mean()['PREVAILING_WAGE'].nlargest(15).plot(kind='bar')

# %% [markdown]
# # Finding Cities With Max Jobs

# %%
f['WORKSITE'].value_counts().head(20)
# Out:
# NEW YORK, NEW YORK            190863
# HOUSTON, TEXAS                 83385
# SAN FRANCISCO, CALIFORNIA      62457
# ATLANTA, GEORGIA               52008
# CHICAGO, ILLINOIS              51167
# SAN JOSE, CALIFORNIA           49582
# SUNNYVALE, CALIFORNIA          34968
# DALLAS, TEXAS                  31509
# BOSTON, MASSACHUSETTS          31336
# REDMOND, WASHINGTON            30574
# CHARLOTTE, NORTH CAROLINA      30176
# IRVING, TEXAS                  29316
# MOUNTAIN VIEW, CALIFORNIA      29245
# SAN DIEGO, CALIFORNIA          28656
# SANTA CLARA, CALIFORNIA        27945
# JERSEY CITY, NEW JERSEY        26822
# SEATTLE, WASHINGTON            26745
# AUSTIN, TEXAS                  26695
# LOS ANGELES, CALIFORNIA        26393
# PHILADELPHIA, PENNSYLVANIA     24104
# Name: WORKSITE, dtype: int64

# %%
f['WORKSITE'].value_counts().head(20).plot(kind='bar')

# %% [markdown]
# # Calculating Number Of States

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3d4fe832267f> in <module>
#       6     return rec
#       7 f.loc[:,'WORKSITE']=f.loc[:,'WORKSITE'].apply(lambda rec: change_NA(rec))
# ----> 8 pring(len(f['WORKSITE'].unique()))
#
# NameError: name 'pring' is not defined
